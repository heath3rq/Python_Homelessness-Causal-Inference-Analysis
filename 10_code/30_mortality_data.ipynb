# %% [markdown]
# ## Mortality Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read Data
#
# - Unzip using the unzip filename command in terminal
#
# - Update relative path to file on url below

# %%
col_names = ["Year", "358 Cause recoded", "State", "County"]

col_width = [(101, 105), (149, 152), (20, 22), (22, 25)]

# put link to the unzipped file
data_07 = pd.read_fwf(
    "../00_source_data/VS07MORT.DUSMCPUB", colspecs=col_width, names=col_names
)

# %% [markdown]
# ### Using data from cdc wonder

# %%
coc_mapping = pd.read_csv("../00_source_data/COC mapping.csv")

# %% [markdown]
# ## Drug Deaths

# %%
alldeathdata0720 = pd.read_csv("../00_source_data/alldrugdeaths0720.txt", sep="\t")
# alldeathdata0720["Year"].value_counts()

# %%
alldata0720merge = pd.merge(
    coc_mapping,
    alldeathdata0720,
    left_on=["STNAME", "FIPS code"],
    right_on=["State", "County Code"],
    how="left",
    indicator=True,
)

# %%
alldata0720merge["_merge"].value_counts()
# Out:
# both          424
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %%
alldeathdata21 = pd.read_csv("../00_source_data/alldrugdeaths21.txt", sep="\t")

# %%
alldata21merge = pd.merge(
    coc_mapping,
    alldeathdata21,
    left_on=["STNAME", "FIPS code"],
    right_on=["State", "County Code"],
    how="left",
    indicator=True,
)

# %%
alldata21merge["_merge"].value_counts()
# Out:
# both          31
# left_only      0
# right_only     0
# Name: _merge, dtype: int64

# %%
alldata = pd.concat([alldata0720merge, alldata21merge])

# %%
alldata0721 = alldata[
    [
        "STNAME",
        "CoC Code",
        "Coc",
        "CTYNAME",
        "FIPS code",
        "Year",
        "Deaths",
    ]
]

# %% [markdown]
# ### Check for Missing drug deaths data

# %%
years = [i for i in range(2007, 2022)]
for county in coc_mapping["CTYNAME"].unique():
    tmp_data = alldata0721[alldata0721["CTYNAME"] == county]
    tmp_year = tmp_data["Year"].unique()
    if len(tmp_year) != 15:
        print(f"Data for {county}")
        print(f"Missing years : {list(set(years) - set(tmp_year))}")
# Out:
# Data for Broomfield County
# Missing years : [2017, 2007, 2008, 2009, 2010, 2011, 2012, 2014, 2015]
# Data for Douglas County
# Missing years : [2008]

# %%
# missing Douglas county
dougcounty = alldata0721[(alldata0721["CTYNAME"] == "Douglas County")]
dougcounty["Year"].value_counts()
# Out:
# 2007.0    1
# 2009.0    1
# 2010.0    1
# 2011.0    1
# 2012.0    1
# 2013.0    1
# 2014.0    1
# 2015.0    1
# 2016.0    1
# 2017.0    1
# 2018.0    1
# 2019.0    1
# 2020.0    1
# 2021.0    1
# Name: Year, dtype: int64

# %%
dougcountyoriginal = alldeathdata0720[(alldeathdata0720["County Code"] == 8035)]
len(dougcountyoriginal["Year"])  # without 2021
# Out:
# 13

# %% [markdown]
# ### Impute Missing Data

# %%
# add 2008 for douglas county as average between 2007 and 2009
doug07deaths = alldata0721[
    (alldata0721["FIPS code"] == 8035) & (alldata0721["Year"] == 2007)
]["Deaths"].values
doug09deaths = alldata0721[
    (alldata0721["FIPS code"] == 8035) & (alldata0721["Year"] == 2009)
]["Deaths"].values
doug08deaths = (doug07deaths + doug09deaths) / 2

# %%
doug_08_data = {
    "STNAME": "Colorado",
    "CoC Code": "CO-503",
    "Coc": "Metropolitan Denver",
    "CTYNAME": "Douglas County",
    "FIPS code": 8035,
    "Year": 2008,
    "Deaths": doug08deaths,
}
df_doug_08 = pd.DataFrame(doug_08_data)

# %%
alldrugdatafinal = pd.concat([alldata0721, df_doug_08], ignore_index=True)
alldrugdatafinal.tail()
# Out:
#          STNAME CoC Code                                                Coc  \
# 451       Texas   TX-700  Houston, Pasadena, Conroe/Harris, Ft. Bend, Mo...
# 452       Texas   TX-700  Houston, Pasadena, Conroe/Harris, Ft. Bend, Mo...
# 453       Texas   TX-503                               Austin/Travis County
# 454  Washington   WA-500                                       Seattle/King
# 455    Colorado   CO-503                                Metropolitan Denver
#
#                CTYNAME  FIPS code    Year  Deaths
# 451  Montgomery County      48339  2021.0   129.0
# 452   Fort Bend County      48157  2021.0    78.0
# 453      Travis County      48453  2021.0   269.0
# 454        King County      53033  2021.0   667.0
# 455     Douglas County       8035  2008.0    20.0

# %%
# fixing broomfield
years_available = alldrugdatafinal[alldrugdatafinal["FIPS code"] == 8014]["Year"]
missing_brooomfield_years = list(set(years) - set(years_available))

tmp_dfs = []

for year in missing_brooomfield_years:
    tmp_data = {
        "STNAME": "Colorado",
        "CoC Code": "CO-503",
        "Coc": "Metropolitan Denver",
        "CTYNAME": "Broomfield County",
        "FIPS code": 8014,
        "Year": year,
        "Deaths": np.NaN,
    }
    df = pd.DataFrame(tmp_data, index=[0])
    tmp_dfs.append(df)

broomfield_df = pd.concat(tmp_dfs, ignore_index=True)
broomfield_df
# Out:
#      STNAME CoC Code                  Coc            CTYNAME  FIPS code  Year  \
# 0  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2017
# 1  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2007
# 2  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2008
# 3  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2009
# 4  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2010
# 5  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2011
# 6  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2012
# 7  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2014
# 8  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2015
#
#    Deaths
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN

# %%
alldrugdatafinal0721 = pd.concat([alldrugdatafinal, broomfield_df], ignore_index=True)
alldrugdatafinal0721["Year"] = alldrugdatafinal0721["Year"].astype(int)
alldrugdatafinal0721.tail(10)
# Out:
#        STNAME CoC Code                  Coc            CTYNAME  FIPS code  \
# 455  Colorado   CO-503  Metropolitan Denver     Douglas County       8035
# 456  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014
# 457  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014
# 458  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014
# 459  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014
# 460  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014
# 461  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014
# 462  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014
# 463  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014
# 464  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014
#
#      Year  Deaths
# 455  2008    20.0
# 456  2017     NaN
# 457  2007     NaN
# 458  2008     NaN
# 459  2009     NaN
# 460  2010     NaN
# 461  2011     NaN
# 462  2012     NaN
# 463  2014     NaN
# 464  2015     NaN

# %% [markdown]
# ### Combine data

# %%
alldrugdatafinal0721 = alldrugdatafinal0721.rename(
    columns={"Deaths": "Drug Deaths"}
).sort_values(by=["CTYNAME", "Year"])
alldrugdatafinal0721
# Out:
#        STNAME CoC Code                  Coc       CTYNAME  FIPS code  Year  \
# 84   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2007
# 85   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2008
# 86   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2009
# 87   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2010
# 88   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2011
# ..        ...      ...                  ...           ...        ...   ...
# 252  Michigan   MI-501              Detroit  Wayne County      26163  2017
# 253  Michigan   MI-501              Detroit  Wayne County      26163  2018
# 254  Michigan   MI-501              Detroit  Wayne County      26163  2019
# 255  Michigan   MI-501              Detroit  Wayne County      26163  2020
# 442  Michigan   MI-501              Detroit  Wayne County      26163  2021
#
#      Drug Deaths
# 84          75.0
# 85          64.0
# 86          71.0
# 87          66.0
# 88          93.0
# ..           ...
# 252        756.0
# 253        775.0
# 254        756.0
# 255        804.0
# 442        911.0
#
# [465 rows x 7 columns]

# %%
# check length
assert len(alldrugdatafinal0721) == len(coc_mapping) * len(years)

# write data
alldrugdatafinal0721.to_csv("../20_intermediate_files/drug_deaths.csv", index=True)

# %% [markdown]
# ## Suicide data

# %%
allmh0720 = pd.read_csv("../00_source_data/allmhdata0720.txt", sep="\t")
# alldeathdata0720["Year"].value_counts()

# %%
allmhdata0720merge = pd.merge(
    coc_mapping,
    allmh0720,
    left_on=["STNAME", "FIPS code"],
    right_on=["State", "County Code"],
    how="left",
    indicator=True,
)

# %%
allmhdata0720merge["_merge"].value_counts()
# Out:
# both          429
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %%
allmh21 = pd.read_csv("../00_source_data/allmhdata21.txt", sep="\t")

# %%
allmh21merge = pd.merge(
    coc_mapping,
    allmh21,
    left_on=["STNAME", "FIPS code"],
    right_on=["State", "County Code"],
    how="left",
    indicator=True,
)

# %%
allmh21merge["_merge"].value_counts()
# Out:
# both          31
# left_only      0
# right_only     0
# Name: _merge, dtype: int64

# %%
allmhdata = pd.concat([allmhdata0720merge, allmh21merge])

# %%
allmh0721 = allmhdata[
    [
        "STNAME",
        "CoC Code",
        "Coc",
        "CTYNAME",
        "FIPS code",
        "Year",
        "Deaths",
    ]
]

# %%
allmh0721.head()
# Out:
#     STNAME CoC Code                    Coc          CTYNAME  FIPS code  \
# 0  Arizona   AZ-502  Phoenix,Mesa/Maricopa  Maricopa County       4013
# 1  Arizona   AZ-502  Phoenix,Mesa/Maricopa  Maricopa County       4013
# 2  Arizona   AZ-502  Phoenix,Mesa/Maricopa  Maricopa County       4013
# 3  Arizona   AZ-502  Phoenix,Mesa/Maricopa  Maricopa County       4013
# 4  Arizona   AZ-502  Phoenix,Mesa/Maricopa  Maricopa County       4013
#
#      Year  Deaths
# 0  2007.0   568.0
# 1  2008.0   540.0
# 2  2009.0   524.0
# 3  2010.0   564.0
# 4  2011.0   621.0

# %% [markdown]
# ### Check missing suicide values

# %%
years = [i for i in range(2007, 2022)]
for county in coc_mapping["CTYNAME"].unique():
    tmp_data = allmh0721[allmh0721["CTYNAME"] == county]
    tmp_year = tmp_data["Year"].unique()
    if len(tmp_year) != 15:
        print(f"Data for {county}")
        print(f"Missing years : {list(set(years) - set(tmp_year))}")
# Out:
# Data for Broomfield County
# Missing years : [2017, 2020, 2008, 2009, 2013]

# %% [markdown]
# ### Impute missing Broomfield data

# %%
# fixing broomfield suicide values
years_available = allmh0721[allmh0721["FIPS code"] == 8014]["Year"]
missing_brooomfield_years = list(set(years) - set(years_available))

tmp_dfs = []

for year in missing_brooomfield_years:
    tmp_data = {
        "STNAME": "Colorado",
        "CoC Code": "CO-503",
        "Coc": "Metropolitan Denver",
        "CTYNAME": "Broomfield County",
        "FIPS code": 8014,
        "Year": year,
        "Deaths": np.NaN,
    }
    df = pd.DataFrame(tmp_data, index=[0])
    tmp_dfs.append(df)

broomfield_mh_df = pd.concat(tmp_dfs, ignore_index=True)
broomfield_mh_df
# Out:
#      STNAME CoC Code                  Coc            CTYNAME  FIPS code  Year  \
# 0  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2017
# 1  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2020
# 2  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2008
# 3  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2009
# 4  Colorado   CO-503  Metropolitan Denver  Broomfield County       8014  2013
#
#    Deaths
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
allmhfinal0721 = pd.concat([allmh0721, broomfield_mh_df], ignore_index=True)
allmhfinal0721["Year"] = allmhfinal0721["Year"].astype(int)
allmhfinal0721.tail(10)
# Out:
#          STNAME CoC Code                                                Coc  \
# 455       Texas   TX-700  Houston, Pasadena, Conroe/Harris, Ft. Bend, Mo...
# 456       Texas   TX-700  Houston, Pasadena, Conroe/Harris, Ft. Bend, Mo...
# 457       Texas   TX-700  Houston, Pasadena, Conroe/Harris, Ft. Bend, Mo...
# 458       Texas   TX-503                               Austin/Travis County
# 459  Washington   WA-500                                       Seattle/King
# 460    Colorado   CO-503                                Metropolitan Denver
# 461    Colorado   CO-503                                Metropolitan Denver
# 462    Colorado   CO-503                                Metropolitan Denver
# 463    Colorado   CO-503                                Metropolitan Denver
# 464    Colorado   CO-503                                Metropolitan Denver
#
#                CTYNAME  FIPS code  Year  Deaths
# 455      Harris County      48201  2021   566.0
# 456  Montgomery County      48339  2021   113.0
# 457   Fort Bend County      48157  2021    87.0
# 458      Travis County      48453  2021   198.0
# 459        King County      53033  2021   295.0
# 460  Broomfield County       8014  2017     NaN
# 461  Broomfield County       8014  2020     NaN
# 462  Broomfield County       8014  2008     NaN
# 463  Broomfield County       8014  2009     NaN
# 464  Broomfield County       8014  2013     NaN

# %% [markdown]
# ### Combining data

# %%
allmhfinal0721 = allmhfinal0721.rename(
    columns={"Deaths": "Suicide Deaths"}
).sort_values(by=["CTYNAME", "Year"])
allmhfinal0721
# Out:
#        STNAME CoC Code                  Coc       CTYNAME  FIPS code  Year  \
# 84   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2007
# 85   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2008
# 86   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2009
# 87   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2010
# 88   Colorado   CO-503  Metropolitan Denver  Adams County       8001  2011
# ..        ...      ...                  ...           ...        ...   ...
# 257  Michigan   MI-501              Detroit  Wayne County      26163  2017
# 258  Michigan   MI-501              Detroit  Wayne County      26163  2018
# 259  Michigan   MI-501              Detroit  Wayne County      26163  2019
# 260  Michigan   MI-501              Detroit  Wayne County      26163  2020
# 447  Michigan   MI-501              Detroit  Wayne County      26163  2021
#
#      Suicide Deaths
# 84             72.0
# 85             69.0
# 86             71.0
# 87             51.0
# 88             66.0
# ..              ...
# 257           203.0
# 258           225.0
# 259           211.0
# 260           218.0
# 447           220.0
#
# [465 rows x 7 columns]

# %%
# check length
assert len(allmhfinal0721) == len(coc_mapping) * len(years)

# write data
allmhfinal0721.to_csv("../20_intermediate_files/suicide_deaths.csv", index=True)
