# %%
## Import dependencies
import pandas as pd
from linearmodels import PanelOLS
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# Per Capita Analysis

# %%
data = pd.read_csv(
    "../20_intermediate_files/project_data_rates.csv", index_col=0
).rename(
    columns={
        "permanent_housing": "permanent_housing_rate",
        "homeless": "homeless_rate",
        "poverty": "poverty_rate",
        "Black or African American": "african_american",
        "American Indian and Alaska Native": "american_indian_n_alaska_native",
        "Asian": "asian",
        "Native Hawaiian and Other Pacific Islander": "pacific_islander",
        "Two or More Races": "multiple_races",
        "Non Hispanic": "non_hispanic",
        "Drug Deaths": "drug_death_rate",
        "Suicide Deaths": "suicide_death_rate",
    }
)
data.head()
# Out:
#   CoC Number                    Coc  Year  permanent_housing_rate  \
# 0     AZ-502  Phoenix,Mesa/Maricopa  2007               52.001543
# 1     AZ-502  Phoenix,Mesa/Maricopa  2008               63.740080
# 2     AZ-502  Phoenix,Mesa/Maricopa  2009               62.861472
# 3     AZ-502  Phoenix,Mesa/Maricopa  2010               78.933918
# 4     AZ-502  Phoenix,Mesa/Maricopa  2011               82.933995
#
#    homeless_rate  poverty_rate  unemployment_rate  Population          Male  \
# 0     218.127624  98946.775104             3200.0     3872962  50412.475000
# 1     181.620069  98615.857511             5100.0     3958263  50450.159578
# 2     196.091006  98737.277325             8900.0     4023132  50471.871169
# 3     183.358278  98824.767488             9500.0     3817117  49473.594862
# 4     150.463014  98699.221313             8500.0     3875371  49431.628611
#
#          Female         White  african_american  \
# 0  49587.525000  87858.904890       4886.079440
# 1  49549.840422  87561.084243       5048.527599
# 2  49528.128831  87320.152558       5202.364725
# 3  50526.405138  85623.940791       5389.722138
# 4  50568.371389  85242.470979       5479.423776
#
#    american_indian_n_alaska_native        asian  pacific_islander  \
# 0                      2248.950545  3007.620524        231.967161
# 1                      2244.696727  3094.817095        236.568414
# 2                      2218.719147  3163.182317        240.484279
# 3                      2610.949573  3675.155883        264.990567
# 4                      2627.387159  3847.347777        266.142261
#
#    multiple_races  non_hispanic      Hispanic  drug_death_rate  \
# 0     1766.477440  69301.067245  30698.932755        14.846518
# 1     1814.305922  68666.685362  31333.314638        13.288657
# 2     1855.096974  68167.934833  31832.065167        14.068641
# 3     2435.241047  70429.489062  29570.510938        15.954449
# 4     2537.228049  70307.797628  29692.202372        16.179096
#
#    suicide_death_rate
# 0           14.665778
# 1           13.642348
# 2           13.024678
# 3           14.775549
# 4           16.024272

# %%
mod = PanelOLS.from_formula(
    "homeless_rate ~ 1 + permanent_housing_rate + Population + poverty_rate + unemployment_rate + drug_death_rate + suicide_death_rate + Female + Hispanic"
    "+ african_american + american_indian_n_alaska_native + asian + pacific_islander + multiple_races"
    "+ EntityEffects + TimeEffects",
    data=data.set_index(["CoC Number", "Year"]),
    drop_absorbed=True,
).fit(cov_type="clustered")
mod.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          homeless_rate   R-squared:                        0.2584
# Estimator:                   PanelOLS   R-squared (Between):             -5.8004
# No. Observations:                 285   R-squared (Within):              -1.0079
# Date:                Sun, Apr 30 2023   R-squared (Overall):             -4.9346
# Time:                        19:53:58   Log-likelihood                   -1689.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      6.4059
# Entities:                          19   P-value                           0.0000
# Avg Obs:                       15.000   Distribution:                  F(13,239)
# Min Obs:                       15.000
# Max Obs:                       15.000   F-statistic (robust):             6.9972
#                                         P-value                           0.0000
# Time periods:                      15   Distribution:                  F(13,239)
# Avg Obs:                       19.000
# Min Obs:                       19.000
# Max Obs:                       19.000
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# Intercept                           7293.2     2936.6     2.4835     0.0137      1508.3   1.308e+04
# Female                             -0.1575     0.0414    -3.8034     0.0002     -0.2390     -0.0759
# Hispanic                           -0.0197     0.0097    -2.0291     0.0436     -0.0388     -0.0006
# Population                          0.0001  6.165e-05     1.7182     0.0871  -1.552e-05      0.0002
# african_american                   -0.0106     0.0113    -0.9417     0.3473     -0.0328      0.0116
# american_indian_n_alaska_native     0.3597     0.0795     4.5255     0.0000      0.2031      0.5162
# asian                               0.0158     0.0146     1.0827     0.2800     -0.0129      0.0444
# drug_death_rate                    -0.6121     1.4759    -0.4147     0.6787     -3.5196      2.2954
# multiple_races                      0.1114     0.0492     2.2618     0.0246      0.0144      0.2084
# pacific_islander                    0.0784     0.2471     0.3174     0.7512     -0.4083      0.5652
# permanent_housing_rate             -0.0020     0.0762    -0.0258     0.9795     -0.1520      0.1481
# poverty_rate                        0.0061     0.0120     0.5075     0.6123     -0.0176      0.0298
# suicide_death_rate                 -2.0725     6.7828    -0.3056     0.7602     -15.434      11.289
# unemployment_rate                   0.0008     0.0016     0.4633     0.6436     -0.0025      0.0040
# ===================================================================================================
#
# F-test for Poolability: 14.450
# P-value: 0.0000
# Distribution: F(32,239)
#
# Included effects: Entity, Time
# """

# %%
test_mod1 = PanelOLS.from_formula(
    "permanent_housing_rate ~ 1 + EntityEffects + TimeEffects",
    data=data.set_index(["CoC Number", "Year"]),
    drop_absorbed=True,
).fit(cov_type="clustered")
test_mod1.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                             PanelOLS Estimation Summary
# ====================================================================================
# Dep. Variable:     permanent_housing_rate   R-squared:                        0.0000
# Estimator:                       PanelOLS   R-squared (Between):              0.0000
# No. Observations:                     285   R-squared (Within):               0.0000
# Date:                    Sun, Apr 30 2023   R-squared (Overall):              0.0000
# Time:                            19:53:58   Log-likelihood                   -1784.0
# Cov. Estimator:                 Clustered
#                                             F-statistic:                          --
# Entities:                              19   P-value                               --
# Avg Obs:                           15.000   Distribution:                         --
# Min Obs:                           15.000
# Max Obs:                           15.000   F-statistic (robust):                 --
#                                             P-value                               --
# Time periods:                          15   Distribution:                         --
# Avg Obs:                           19.000
# Min Obs:                           19.000
# Max Obs:                           19.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      279.58     7.9729     35.066     0.0000      263.88      295.28
# ==============================================================================
#
# F-test for Poolability: 49.046
# P-value: 0.0000
# Distribution: F(32,252)
#
# Included effects: Entity, Time
# """

# %%
test_mod2 = PanelOLS.from_formula(
    "Female ~ 1 + Male",
    data=data.set_index(["CoC Number", "Year"]),
    drop_absorbed=True,
).fit(cov_type="clustered")
test_mod2.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 Female   R-squared:                        1.0000
# Estimator:                   PanelOLS   R-squared (Between):              1.0000
# No. Observations:                 285   R-squared (Within):               1.0000
# Date:                Sun, Apr 30 2023   R-squared (Overall):              1.0000
# Time:                        19:53:58   Log-likelihood                    6733.3
# Cov. Estimator:             Clustered
#                                         F-statistic:                   2.102e+30
# Entities:                          19   P-value                           0.0000
# Avg Obs:                       15.000   Distribution:                   F(1,283)
# Min Obs:                       15.000
# Max Obs:                       15.000   F-statistic (robust):          2.506e+30
#                                         P-value                           0.0000
# Time periods:                      15   Distribution:                   F(1,283)
# Avg Obs:                       19.000
# Min Obs:                       19.000
# Max Obs:                       19.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept       1e+05  3.083e-11  3.244e+15     0.0000       1e+05       1e+05
# Male          -1.0000  6.317e-16 -1.583e+15     0.0000     -1.0000     -1.0000
# ==============================================================================
#
#
# """

# %%
data.loc[:, "permanent_housing_rate"].describe()
# Out:
# count     285.000000
# mean      279.581747
# std       340.871202
# min         6.085049
# 25%        90.039045
# 50%       155.701361
# 75%       307.150067
# max      2485.486158
# Name: permanent_housing_rate, dtype: float64

# %%
(
    data.loc[data.loc[:, "Year"] == 2021, "permanent_housing_rate"].mean()
    - data.loc[data.loc[:, "Year"] == 2007, "permanent_housing_rate"].mean()
) / (2021 - 2007)
# Out:
# 18.161157724747593

# %%
(data.loc[:, "Year"] - data.loc[:, "Year"].shift()).value_counts()
# Out:
#  1.0     266
# -14.0     18
# Name: Year, dtype: int64

# %%
data.loc[:, "perm_housing_pct_chg"] = (
    data.loc[:, "permanent_housing_rate"]
    / data.loc[:, "permanent_housing_rate"].shift()
    - 1
)

# %%
data_w_pct_chg = data.set_index(["CoC Number", "Year"]).drop(index=2007, level=1)

# %%
mod2 = PanelOLS.from_formula(
    "homeless_rate ~ Population + poverty_rate + unemployment_rate + drug_death_rate + suicide_death_rate + Female + Hispanic"
    "+ White + perm_housing_pct_chg + african_american + american_indian_n_alaska_native + asian + pacific_islander + multiple_races"
    "+ EntityEffects + TimeEffects",
    data=data_w_pct_chg,
    drop_absorbed=True,
).fit(cov_type="clustered")
mod2.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          homeless_rate   R-squared:                        0.2456
# Estimator:                   PanelOLS   R-squared (Between):             -3.2338
# No. Observations:                 266   R-squared (Within):              -0.8066
# Date:                Sun, Apr 30 2023   R-squared (Overall):             -2.8707
# Time:                        19:53:58   Log-likelihood                   -1557.3
# Cov. Estimator:             Clustered
#                                         F-statistic:                      5.5354
# Entities:                          19   P-value                           0.0000
# Avg Obs:                       14.000   Distribution:                  F(13,221)
# Min Obs:                       14.000
# Max Obs:                       14.000   F-statistic (robust):             359.78
#                                         P-value                           0.0000
# Time periods:                      15   Distribution:                  F(13,221)
# Avg Obs:                       17.733
# Min Obs:                       0.0000
# Max Obs:                       19.000
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# Female                             -0.1681     0.0469    -3.5838     0.0004     -0.2605     -0.0757
# Hispanic                           -0.0234     0.0117    -2.0025     0.0465     -0.0464     -0.0004
# Population                       6.943e-05  6.454e-05     1.0758     0.2832  -5.776e-05      0.0002
# White                               0.0714     0.0340     2.0974     0.0371      0.0043      0.1385
# african_american                    0.0665     0.0407     1.6360     0.1033     -0.0136      0.1467
# american_indian_n_alaska_native     0.4615     0.0827     5.5774     0.0000      0.2984      0.6246
# asian                               0.0826     0.0272     3.0416     0.0026      0.0291      0.1362
# drug_death_rate                    -0.0905     1.3818    -0.0655     0.9479     -2.8136      2.6327
# multiple_races                      0.1798     0.0539     3.3365     0.0010      0.0736      0.2860
# pacific_islander                    0.0049     0.2670     0.0183     0.9854     -0.5213      0.5311
# perm_housing_pct_chg               -20.773     26.629    -0.7801     0.4362     -73.253      31.707
# poverty_rate                        0.0140     0.0185     0.7591     0.4486     -0.0224      0.0504
# suicide_death_rate                  2.8516     6.2809     0.4540     0.6503     -9.5265      15.230
# unemployment_rate                   0.0004     0.0017     0.2517     0.8015     -0.0029      0.0037
# ===================================================================================================
#
# F-test for Poolability: 25.071
# P-value: 0.0000
# Distribution: F(31,221)
#
# Included effects: Entity, Time
# """

# %%
mod.resids
# Out:
# CoC Number  Year
# AZ-502      2007    -50.536507
#             2008    -70.691888
#             2009     14.809143
#             2010     56.369679
#             2011     34.143417
#                        ...
# WA-500      2017     50.268256
#             2018     55.393230
#             2019    -16.399662
#             2020    -20.845343
#             2021   -190.987997
# Name: residual, Length: 285, dtype: float64

# %%
data.corr(numeric_only=True)
# Out:
#                                      Year  permanent_housing_rate  \
# Year                             1.000000                0.215273
# permanent_housing_rate           0.215273                1.000000
# homeless_rate                   -0.157463                0.683066
# poverty_rate                     0.044940               -0.579332
# unemployment_rate               -0.102237               -0.128192
# Population                       0.036546               -0.279464
# Male                            -0.023645               -0.297272
# Female                           0.023645                0.297272
# White                           -0.111439               -0.539197
# african_american                -0.008523                0.341193
# american_indian_n_alaska_native  0.160537               -0.299962
# asian                            0.111121                0.218752
# pacific_islander                 0.064591               -0.081861
# multiple_races                   0.458532                0.167562
# non_hispanic                    -0.069063                0.399893
# Hispanic                         0.069063               -0.399893
# drug_death_rate                  0.508867                0.493541
# suicide_death_rate               0.110317               -0.438602
# perm_housing_pct_chg            -0.044679                0.119527
#
#                                  homeless_rate  poverty_rate  \
# Year                                 -0.157463      0.044940
# permanent_housing_rate                0.683066     -0.579332
# homeless_rate                         1.000000     -0.481101
# poverty_rate                         -0.481101      1.000000
# unemployment_rate                     0.050777      0.189647
# Population                           -0.140101      0.410623
# Male                                 -0.320818      0.493421
# Female                                0.320818     -0.493421
# White                                -0.575664      0.396055
# african_american                      0.363966     -0.490325
# american_indian_n_alaska_native      -0.339134      0.335988
# asian                                 0.245654      0.189568
# pacific_islander                     -0.000419      0.260622
# multiple_races                        0.064413      0.128079
# non_hispanic                          0.405925     -0.344979
# Hispanic                             -0.405925      0.344979
# drug_death_rate                       0.092520     -0.230387
# suicide_death_rate                   -0.499405      0.398057
# perm_housing_pct_chg                  0.052974     -0.137340
#
#                                  unemployment_rate  Population      Male  \
# Year                                     -0.102237    0.036546 -0.023645
# permanent_housing_rate                   -0.128192   -0.279464 -0.297272
# homeless_rate                             0.050777   -0.140101 -0.320818
# poverty_rate                              0.189647    0.410623  0.493421
# unemployment_rate                         1.000000    0.392164 -0.164480
# Population                                0.392164    1.000000 -0.089395
# Male                                     -0.164480   -0.089395  1.000000
# Female                                    0.164480    0.089395 -1.000000
# White                                     0.081546    0.187978  0.599165
# african_american                          0.014145   -0.175787 -0.867411
# american_indian_n_alaska_native           0.114877    0.342926  0.344374
# asian                                    -0.123655    0.013182  0.468610
# pacific_islander                         -0.184135   -0.027188  0.559666
# multiple_races                           -0.167013   -0.149604  0.451702
# non_hispanic                             -0.065584   -0.534686 -0.375348
# Hispanic                                  0.065584    0.534686  0.375348
# drug_death_rate                          -0.111447   -0.272898 -0.285403
# suicide_death_rate                        0.039398   -0.190039  0.458763
# perm_housing_pct_chg                      0.015836   -0.028764 -0.056800
#
#                                    Female     White  african_american  \
# Year                             0.023645 -0.111439         -0.008523
# permanent_housing_rate           0.297272 -0.539197          0.341193
# homeless_rate                    0.320818 -0.575664          0.363966
# poverty_rate                    -0.493421  0.396055         -0.490325
# unemployment_rate                0.164480  0.081546          0.014145
# Population                       0.089395  0.187978         -0.175787
# Male                            -1.000000  0.599165         -0.867411
# Female                           1.000000 -0.599165          0.867411
# White                           -0.599165  1.000000         -0.756061
# african_american                 0.867411 -0.756061          1.000000
# american_indian_n_alaska_native -0.344374  0.579535         -0.581660
# asian                           -0.468610 -0.252190         -0.438244
# pacific_islander                -0.559666  0.227629         -0.590180
# multiple_races                  -0.451702  0.084932         -0.507110
# non_hispanic                     0.375348 -0.607014          0.560476
# Hispanic                        -0.375348  0.607014         -0.560476
# drug_death_rate                  0.285403 -0.329660          0.323356
# suicide_death_rate              -0.458763  0.578403         -0.414047
# perm_housing_pct_chg             0.056800 -0.069778          0.044805
#
#                                  american_indian_n_alaska_native     asian  \
# Year                                                    0.160537  0.111121
# permanent_housing_rate                                 -0.299962  0.218752
# homeless_rate                                          -0.339134  0.245654
# poverty_rate                                            0.335988  0.189568
# unemployment_rate                                       0.114877 -0.123655
# Population                                              0.342926  0.013182
# Male                                                    0.344374  0.468610
# Female                                                 -0.344374 -0.468610
# White                                                   0.579535 -0.252190
# african_american                                       -0.581660 -0.438244
# american_indian_n_alaska_native                         1.000000  0.013908
# asian                                                   0.013908  1.000000
# pacific_islander                                        0.331337  0.495723
# multiple_races                                          0.298170  0.553289
# non_hispanic                                           -0.618318  0.006872
# Hispanic                                                0.618318 -0.006872
# drug_death_rate                                        -0.163977 -0.058566
# suicide_death_rate                                      0.310802 -0.210918
# perm_housing_pct_chg                                    0.002739  0.025064
#
#                                  pacific_islander  multiple_races  \
# Year                                     0.064591        0.458532
# permanent_housing_rate                  -0.081861        0.167562
# homeless_rate                           -0.000419        0.064413
# poverty_rate                             0.260622        0.128079
# unemployment_rate                       -0.184135       -0.167013
# Population                              -0.027188       -0.149604
# Male                                     0.559666        0.451702
# Female                                  -0.559666       -0.451702
# White                                    0.227629        0.084932
# african_american                        -0.590180       -0.507110
# american_indian_n_alaska_native          0.331337        0.298170
# asian                                    0.495723        0.553289
# pacific_islander                         1.000000        0.840092
# multiple_races                           0.840092        1.000000
# non_hispanic                            -0.201986       -0.061461
# Hispanic                                 0.201986        0.061461
# drug_death_rate                         -0.111725        0.154872
# suicide_death_rate                       0.322457        0.263273
# perm_housing_pct_chg                     0.003249        0.011958
#
#                                  non_hispanic  Hispanic  drug_death_rate  \
# Year                                -0.069063  0.069063         0.508867
# permanent_housing_rate               0.399893 -0.399893         0.493541
# homeless_rate                        0.405925 -0.405925         0.092520
# poverty_rate                        -0.344979  0.344979        -0.230387
# unemployment_rate                   -0.065584  0.065584        -0.111447
# Population                          -0.534686  0.534686        -0.272898
# Male                                -0.375348  0.375348        -0.285403
# Female                               0.375348 -0.375348         0.285403
# White                               -0.607014  0.607014        -0.329660
# african_american                     0.560476 -0.560476         0.323356
# american_indian_n_alaska_native     -0.618318  0.618318        -0.163977
# asian                                0.006872 -0.006872        -0.058566
# pacific_islander                    -0.201986  0.201986        -0.111725
# multiple_races                      -0.061461  0.061461         0.154872
# non_hispanic                         1.000000 -1.000000         0.362907
# Hispanic                            -1.000000  1.000000        -0.362907
# drug_death_rate                      0.362907 -0.362907         1.000000
# suicide_death_rate                  -0.054915  0.054915         0.070483
# perm_housing_pct_chg                 0.037832 -0.037832        -0.035826
#
#                                  suicide_death_rate  perm_housing_pct_chg
# Year                                       0.110317             -0.044679
# permanent_housing_rate                    -0.438602              0.119527
# homeless_rate                             -0.499405              0.052974
# poverty_rate                               0.398057             -0.137340
# unemployment_rate                          0.039398              0.015836
# Population                                -0.190039             -0.028764
# Male                                       0.458763             -0.056800
# Female                                    -0.458763              0.056800
# White                                      0.578403             -0.069778
# african_american                          -0.414047              0.044805
# american_indian_n_alaska_native            0.310802              0.002739
# asian                                     -0.210918              0.025064
# pacific_islander                           0.322457              0.003249
# multiple_races                             0.263273              0.011958
# non_hispanic                              -0.054915              0.037832
# Hispanic                                   0.054915             -0.037832
# drug_death_rate                            0.070483             -0.035826
# suicide_death_rate                         1.000000             -0.076591
# perm_housing_pct_chg                      -0.076591              1.000000

# %%
(data.loc[:, "homeless_rate"] / data.loc[:, "permanent_housing_rate"]).hist(bins=20)
plt.show()

# %%
mod.resids.hist()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

# Residual plot
pd.concat(
    (data.set_index(["CoC Number", "Year"]).loc[:, "Female"], mod.resids), axis=1
).rename(columns={0: "residuals"}).plot.scatter(
    "Female", "residual", title="Residual Plot", ax=ax1)

# qq plot
sm.qqplot(mod.resids, stats.t, fit=True, line="45", ax=ax2)
ax2.set_title("QQ Plot")

plt.show()

# %%
pd.concat(
    (
        data.set_index(["CoC Number", "Year"]).loc[:, "permanent_housing_rate"],
        mod.resids,
    ),
    axis=1,
).rename(columns={0: "residuals"}).plot.scatter(
    "permanent_housing_rate", "residual", title="Residual Plot"
)
plt.show()

# %% [markdown]
# # Normalized by 2007 Homeless Populations

# %% [markdown]
# Importing Data

# %%
data2 = pd.read_csv("../20_intermediate_files/project_data.csv", index_col=0)
data2.head()
# Out:
#   CoC Number                    Coc  Year  permanent_housing  homeless  \
# 0     AZ-502  Phoenix,Mesa/Maricopa  2007             2014.0      8448
# 1     AZ-502  Phoenix,Mesa/Maricopa  2008             2523.0      7189
# 2     AZ-502  Phoenix,Mesa/Maricopa  2009             2529.0      7889
# 3     AZ-502  Phoenix,Mesa/Maricopa  2010             3013.0      6999
# 4     AZ-502  Phoenix,Mesa/Maricopa  2011             3214.0      5831
#
#      poverty  unemployment_rate  Population     Male   Female    White  \
# 0  3832171.0                3.2     3872962  1952456  1920506  3402742
# 1  3903475.0                5.1     3958263  1996950  1961313  3465898
# 2  3972331.0                8.9     4023132  2030550  1992582  3513005
# 3  3772257.0                9.5     3817117  1888465  1928652  3268366
# 4  3824961.0                8.5     3875371  1915659  1959712  3303462
#
#    Black or African American  American Indian and Alaska Native   Asian  \
# 0                     189236                              87101  116484
# 1                     199834                              88851  122501
# 2                     209298                              89262  127259
# 3                     205732                              99663  140285
# 4                     212348                             101821  149099
#
#    Native Hawaiian and Other Pacific Islander  Two or More Races  \
# 0                                        8984              68415
# 1                                        9364              71815
# 2                                        9675              74633
# 3                                       10115              92956
# 4                                       10314              98327
#
#    Non Hispanic  Hispanic  Drug Deaths  Suicide Deaths
# 0       2684004   1188958        575.0           568.0
# 1       2718008   1240255        526.0           540.0
# 2       2742486   1280646        566.0           524.0
# 3       2688376   1128741        609.0           564.0
# 4       2724688   1150683        627.0           621.0

# %% [markdown]
# Estimating Unemployed Population to later Normalize by Homeless Population

# %%
data2.loc[:, "Estimated Unemployed Persons"] = (
    data2.loc[:, "unemployment_rate"] * data2.loc[:, "Population"]
)

# %% [markdown]
# Transforming Data to Get the 2007 Homeless Population for each COC

# %%
data2 = data2.merge(
    data2.loc[data2.loc[:, "Year"] == 2007, ["CoC Number", "homeless"]].rename(
        columns={"homeless": "2007 homeless"}
    ),
    how="left",
    on="CoC Number",
    validate="m:1",
)

# %% [markdown]
# Normalizing Data by Dividing Each Variable by the COC's 2007 Homeless Population

# %%
normalized_data2 = (
    data2.loc[
        :,
        data2.columns[
            ~data2.columns.isin(
                ["CoC Number", "Coc", "Year", "unemployment_rate", "2007 homeless"]
            )
        ],
    ]
    .divide(data2.loc[:, "2007 homeless"], axis=0)
    .rename(columns=lambda x: f"Normalized {x}")
)

# %%
normalized_data2 = pd.concat(
    (
        data2.loc[
            :,
            [
                "CoC Number",
                "Coc",
                "Year",
            ],
        ],
        normalized_data2,
    ),
    axis=1,
)

# %% [markdown]
# Renaming columns to use with Panel OLS from Formula function

# %%
normalized_data2 = normalized_data2.rename(columns=lambda x: x.replace(" ", "_"))

# %%
normalized_data2.columns
# Out:
# Index(['CoC_Number', 'Coc', 'Year', 'Normalized_permanent_housing',
#        'Normalized_homeless', 'Normalized_poverty', 'Normalized_Population',
#        'Normalized_Male', 'Normalized_Female', 'Normalized_White',
#        'Normalized_Black_or_African_American',
#        'Normalized_American_Indian_and_Alaska_Native', 'Normalized_Asian',
#        'Normalized_Native_Hawaiian_and_Other_Pacific_Islander',
#        'Normalized_Two_or_More_Races', 'Normalized_Non_Hispanic',
#        'Normalized_Hispanic', 'Normalized_Drug_Deaths',
#        'Normalized_Suicide_Deaths', 'Normalized_Estimated_Unemployed_Persons'],
#       dtype='object')

# %%
norm_mod2 = PanelOLS.from_formula(
    "Normalized_homeless ~ 1 + Normalized_permanent_housing + Normalized_poverty + Normalized_Population + Normalized_Female "
    "+ Normalized_Black_or_African_American + Normalized_American_Indian_and_Alaska_Native + Normalized_Asian "
    "+ Normalized_Native_Hawaiian_and_Other_Pacific_Islander + Normalized_Two_or_More_Races + Normalized_Hispanic "
    "+ Normalized_Drug_Deaths + Normalized_Suicide_Deaths + Normalized_Estimated_Unemployed_Persons"
    # + permanent_housing_rate + Population + poverty_rate + unemployment_rate + drug_death_rate + suicide_death_rate + Female + Hispanic"
    # "+ african_american + american_indian_n_alaska_native + asian + pacific_islander + multiple_races"
    "+ EntityEffects + TimeEffects",
    data=normalized_data2.set_index(["CoC_Number", "Year"]),
    drop_absorbed=True,
).fit(cov_type="clustered")
norm_mod2.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Normalized_homeless   R-squared:                        0.2512
# Estimator:                    PanelOLS   R-squared (Between):             -6.0847
# No. Observations:                  285   R-squared (Within):               0.1312
# Date:                 Sun, Apr 30 2023   R-squared (Overall):             -3.9232
# Time:                         19:53:59   Log-likelihood                    111.81
# Cov. Estimator:              Clustered
#                                          F-statistic:                      6.1687
# Entities:                           19   P-value                           0.0000
# Avg Obs:                        15.000   Distribution:                  F(13,239)
# Min Obs:                        15.000
# Max Obs:                        15.000   F-statistic (robust):             6.3744
#                                          P-value                           0.0000
# Time periods:                       15   Distribution:                  F(13,239)
# Avg Obs:                        19.000
# Min Obs:                        19.000
# Max Obs:                        19.000
#
#                                                    Parameter Estimates
# =========================================================================================================================
#                                                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------------------------------
# Intercept                                                 1.0704     0.3895     2.7485     0.0064      0.3032      1.8376
# Normalized_American_Indian_and_Alaska_Native              0.1583     0.0429     3.6896     0.0003      0.0738      0.2428
# Normalized_Asian                                          0.0078     0.0057     1.3792     0.1691     -0.0033      0.0190
# Normalized_Black_or_African_American                     -0.0057     0.0109    -0.5260     0.5994     -0.0272      0.0157
# Normalized_Drug_Deaths                                   -1.1063     0.6434    -1.7195     0.0868     -2.3737      0.1611
# Normalized_Estimated_Unemployed_Persons                1.808e-05  8.941e-06     2.0223     0.0443    4.68e-07    3.57e-05
# Normalized_Female                                        -0.0971     0.0249    -3.8986     0.0001     -0.1462     -0.0481
# Normalized_Hispanic                                      -0.0121     0.0040    -3.0133     0.0029     -0.0201     -0.0042
# Normalized_Native_Hawaiian_and_Other_Pacific_Islander     0.1854     0.1551     1.1954     0.2331     -0.1201      0.4909
# Normalized_Population                                     0.0362     0.0158     2.2956     0.0226      0.0051      0.0673
# Normalized_Suicide_Deaths                                -1.4194     4.2151    -0.3367     0.7366     -9.7229      6.8842
# Normalized_Two_or_More_Races                             -0.0246     0.0310    -0.7936     0.4282     -0.0858      0.0365
# Normalized_permanent_housing                              0.1948     0.0805     2.4205     0.0162      0.0363      0.3533
# Normalized_poverty                                        0.0141     0.0084     1.6812     0.0940     -0.0024      0.0305
# =========================================================================================================================
#
# F-test for Poolability: 10.618
# P-value: 0.0000
# Distribution: F(32,239)
#
# Included effects: Entity, Time
# """

# %%
pd.concat(
    (
        normalized_data2.set_index(["CoC_Number", "Year"]).loc[:, "Normalized_Female"],
        norm_mod2.resids,
    ),
    axis=1,
).plot.scatter("Normalized_Female", "residual", title="Residual Plot")
plt.show()

# %%
pd.concat(
    (
        normalized_data2.set_index(["CoC_Number", "Year"]).loc[
            :, "Normalized_permanent_housing"
        ],
        norm_mod2.resids,
    ),
    axis=1,
).plot.scatter("Normalized_permanent_housing", "residual", title="Residual Plot")
plt.show()

# %%
import statsmodels.api as sm
import scipy.stats as stats
import matplotlib.pyplot as plt

sm.qqplot(norm_mod2.resids, stats.t, fit=True, line="45")
plt.title("QQ Plot")
plt.show()
